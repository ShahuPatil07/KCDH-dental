# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Verify the installation
try:
    import tensorflow as tf
    print(tf.__version__)
except ModuleNotFoundError:
    print("TensorFlow is not installed.")
# Out:
# 2.17.0

# %%
# Import necessary libraries
import torch

# Check if CUDA (GPU acceleration) is available
if torch.cuda.is_available():
    # Get the name of the GPU device
    gpu_name = torch.cuda.get_device_name(0)
    # Get the available GPU memory
    gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3  # Convert bytes to GB
    # Print the GPU specs
    print(f'Using GPU: {gpu_name}, GPU Memory: {gpu_memory:.2f} GB')
else:
    print('CUDA is not available. Running on CPU.')
# Out:
# Using GPU: NVIDIA A100-SXM4-40GB, GPU Memory: 39.56 GB

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Oct  5 18:42:26 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              42W / 400W |      5MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Input, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.losses import Loss
from tensorflow.keras.metrics import AUC
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
from collections import defaultdict
from PIL import Image


def print_config():
    print("Configuration:")
    print("TensorFlow version:", tf.__version__)
    print("Keras version:", tf.keras.__version__)
    print("CUDA available:", tf.test.is_built_with_cuda())
    print("GPU available:", tf.config.list_physical_devices('GPU'))

print_config()
# Out:
# Configuration:
# TensorFlow version: 2.17.0
# Keras version: 3.4.1
# CUDA available: True
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Define paths
images_path = 'drive/MyDrive/dataset_final/alphakappa_images'
labels_path = 'drive/MyDrive/dataset_final/labels_BINARY'
notes_path = 'drive/MyDrive/dataset_final/notes.json'
classes_path = 'drive/MyDrive/dataset_final/classes_BINARY.txt'

# %%
# Define the mapping from class IDs to category names
category_mapping = {
    0: "Infected",
    1: "No Cavity"
}

# Directory where the text files are located
directory = 'drive/MyDrive/dataset_final/labels_BINARY'

# Initialize a dictionary to count occurrences of each category
category_count = defaultdict(int)

# Iterate through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r') as file:
            # Read each line in the file (assuming each line is a separate image)
            for line in file:
                # Split the line and get the class label (first value)
                values = line.strip().split()
                if values:
                    class_label = int(values[0])  # assuming the first value is the class label
                    category_name = category_mapping.get(class_label)
                    if category_name:
                        category_count[category_name] += 1

# Print the count of images in each category
print("Number of images per category:")
for category, count in category_count.items():
    print(f"{category}: {count}")

# Plotting the results as a bar chart
categories = list(category_count.keys())
counts = list(category_count.values())

plt.figure(figsize=(8, 6))
plt.bar(categories, counts, color='purple')
plt.xlabel('Categories')
plt.ylabel('Number of Images')
plt.title('Number of Images per Category')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
# Out:
# Number of images per category:
# No Cavity: 340
# Infected: 766

# %%
# Load notes.json
with open(notes_path) as f:
    notes = json.load(f)

# Load classes
with open(classes_path) as f:
    classes = [line.strip() for line in f.readlines()]

# Prepare dataset
image_files = sorted([f for f in os.listdir(images_path)])
label_files = sorted([f for f in os.listdir(labels_path) if f.endswith('.txt')])

print(len(image_files))
print(len(label_files))
# Check consistency
if len(image_files) != len(label_files):
    raise ValueError("Number of images and labels must be the same.")

# Ensure ordering is correct and consistent
image_files = sorted(image_files)
label_files = sorted(label_files)

# Generate a random seed
random_seed = np.random.randint(0, 10000)

# Split dataset into train and test
train_images, test_images, train_labels, test_labels = train_test_split(
    image_files, label_files, train_size=797, test_size=200, random_state=random_seed, shuffle=True
)

print(f"Using random state: {random_seed}")
# Out:
# 997
# 997
# Using random state: 4455

# %%
# Function to load and preprocess images
def load_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img = image.img_to_array(img)
    img = img / 255.0  # Rescale the image
    return img

# %%
# Prepare training data
train_data = []
train_targets = []

for img_file, lbl_file in zip(train_images, train_labels):
    img = load_image(os.path.join(images_path, img_file))
    with open(os.path.join(labels_path, lbl_file)) as f:
        label = int(f.readline().strip().split()[0])
    train_data.append(img)
    train_targets.append(label)

train_data = np.array(train_data)
train_targets = np.array(train_targets)

# %%
# Prepare test data
test_data = []
test_targets = []

for img_file, lbl_file in zip(test_images, test_labels):
    img = load_image(os.path.join(images_path, img_file))
    with open(os.path.join(labels_path, lbl_file)) as f:
        label = int(f.readline().strip().split()[0])
    test_data.append(img)
    test_targets.append(label)

test_data = np.array(test_data)
test_targets = np.array(test_targets)

# %%
print('Train data shape:', train_data.shape)  # Should be (397, 224, 224, 3)
print('Train targets shape:', train_targets.shape)  # Should be (397,)
print('Test data shape:', test_data.shape)  # Should be (99, 224, 224, 3)
print('Test targets shape:', test_targets.shape)  # Should be (99,)
# Out:
# Train data shape: (797, 224, 224, 3)
# Train targets shape: (797,)
# Test data shape: (200, 224, 224, 3)
# Test targets shape: (200,)

# %%
# Display dataset information
total_image_count = len(train_data) + len(test_data)
image_dimensions = train_data[0].shape if len(train_data) > 0 else (224, 224, 3)
label_names = [category['name'] for category in notes['categories']]
label_counts = np.bincount(train_targets)

print(f"Total image count: {total_image_count}")
print(f"Image dimensions: {image_dimensions}")
print("Label names: ", label_names)
print("Label counts: ", label_counts)
# Out:
# Total image count: 997
# Image dimensions: (224, 224, 3)
# Label names:  ['Extraction', 'No Cavity', 'Surface Filling', 'Root Canal Treatment']
# Label counts:  [545 252]

# %%
# Visualise some randomly picked examples from the dataset
# Number of images to display
num_images_to_display = 9

# Randomly pick some examples from the dataset
random_indices = np.random.randint(0, len(train_data), size=num_images_to_display)

# Plot the randomly picked examples
plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    img = train_data[idx]
    label = train_targets[idx]
    plt.subplot(3, 3, i + 1)
    plt.imshow(img)
    plt.title(classes[label])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Focal Loss

# %%
# Define Focal Loss
class FocalLoss(Loss):
    def __init__(self, gamma=2., alpha=0.25, **kwargs):
        self.gamma = gamma
        self.alpha = alpha
        super(FocalLoss, self).__init__(**kwargs)

    def call(self, y_true, y_pred):
        y_true = K.cast(y_true, dtype='float32')
        alpha = K.constant(self.alpha, dtype='float32')
        gamma = K.constant(self.gamma, dtype='float32')

        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())

        cross_entropy = -y_true * K.log(y_pred)
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy
        return K.sum(loss, axis=1)

# %% [markdown]
# ## Asymmetrical Loss

# %%
class CategoricalCrossentropyLoss(tf.keras.losses.Loss):
    def __init__(self, from_logits=False, label_smoothing=0, **kwargs):
        super(CategoricalCrossentropyLoss, self).__init__(**kwargs)
        self.from_logits = from_logits
        self.label_smoothing = label_smoothing

    def call(self, y_true, y_pred):
        # Optionally smooth labels
        if self.label_smoothing > 0:
            num_classes = tf.cast(tf.shape(y_true)[-1], tf.float32)
            y_true = (1 - self.label_smoothing) * y_true + self.label_smoothing / num_classes

        # Compute the cross-entropy loss
        if self.from_logits:
            loss = tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)
        else:
            # Ensure the predictions are valid probabilities
            y_pred = tf.clip_by_value(y_pred, clip_value_min=1e-8, clip_value_max=1.0)
            loss = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)

        return tf.reduce_mean(loss)

# %% [markdown]
# ## Model Training for 6 Configurations

# %%
# Function to compile and train the model
def compile_and_train(model, loss_fn, optimizer, train_data, train_targets, val_data, val_targets, class_weights=None, model_name='', epochs=1000, batch_size=32):
    # Compile the model
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy', AUC(name='auc')])

    # Define callbacks
    checkpoint = ModelCheckpoint(f'{model_name}_best.keras', monitor='val_auc', save_best_only=True, mode='max')
    early_stopping = EarlyStopping(monitor='val_auc', patience=25, mode='max')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=25, min_lr=1e-12, mode='min')

    # Train the model
    history = model.fit(
        train_data, train_targets,
        validation_data=(val_data, val_targets),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[checkpoint, early_stopping, reduce_lr],
        class_weight=class_weights  # Use class_weights only when not None
    )
    return history

# Convert labels to categorical
train_targets_categorical = to_categorical(train_targets, num_classes=len(classes))
val_targets_categorical = to_categorical(test_targets, num_classes=len(classes))

# Preprocess DenseNet model
def build_densenet_model():
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(len(classes), activation='softmax', dtype='float32')(x)
    return Model(inputs=base_model.input, outputs=predictions)

# Preprocess CNN model
def build_cnn_model():
    input_tensor = Input(shape=(224, 224, 3))
    x = Conv2D(32, (3, 3), activation='relu')(input_tensor)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(len(classes), activation='softmax', dtype='float32')(x)
    return Model(inputs=input_tensor, outputs=predictions)

# Get class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_targets), y=train_targets)
class_weights = {i: class_weights[i] for i in range(len(class_weights))}

# Train DenseNet with FocalLoss (no class weights)
densenet_focal = build_densenet_model()
history_densenet_focal = compile_and_train(densenet_focal, FocalLoss(), Adam(learning_rate=1e-3),
                                           train_data, train_targets_categorical, test_data, val_targets_categorical,
                                           class_weights=None, model_name='densenet_focal')

# Train DenseNet with Categorical cross-entropy (no class weights)
densenet_cce = build_densenet_model()
history_densenet_cce = compile_and_train(densenet_cce, CategoricalCrossentropyLoss(), Adam(learning_rate=1e-3),
                                         train_data, train_targets_categorical, test_data, val_targets_categorical,
                                         class_weights=None, model_name='densenet_cce')

# Train DenseNet with Binary Cross-Entropy Loss (with class weights)
densenet_bce = build_densenet_model()
history_densenet_bce = compile_and_train(densenet_bce, 'binary_crossentropy', Adam(learning_rate=1e-3),
                                         train_data, train_targets_categorical, test_data, val_targets_categorical,
                                         class_weights=class_weights, model_name='densenet_bce')

# Train CNN with FocalLoss (no class weights)
cnn_focal = build_cnn_model()
history_cnn_focal = compile_and_train(cnn_focal, FocalLoss(), SGD(learning_rate=1e-3, momentum=0.9),
                                      train_data, train_targets_categorical, test_data, val_targets_categorical,
                                      class_weights=None, model_name='cnn_focal')

# Train CNN with Categorical cross-entropy (no class weights)
cnn_cce = build_cnn_model()
history_cnn_cce = compile_and_train(cnn_cce, CategoricalCrossentropyLoss(), SGD(learning_rate=1e-3, momentum=0.9),
                                    train_data, train_targets_categorical, test_data, val_targets_categorical,
                                    class_weights=None, model_name='cnn_cce')

# Train CNN with Binary Cross-Entropy Loss (with class weights)
cnn_bce = build_cnn_model()
history_cnn_bce = compile_and_train(cnn_bce, 'binary_crossentropy', SGD(learning_rate=1e-3, momentum=0.9),
                                    train_data, train_targets_categorical, test_data, val_targets_categorical,
                                    class_weights=class_weights, model_name='cnn_bce')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 283s 5s/step - accuracy: 0.6019 - auc: 0.6585 - loss: 0.2225 - val_accuracy: 0.2700 - val_auc: 0.2703 - val_loss: 2.8869 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6641 - auc: 0.7448 - loss: 0.0377 - val_accuracy: 0.2700 - val_auc: 0.3030 - val_loss: 0.1229 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.7525 - auc: 0.8257 - loss: 0.0350 - val_accuracy: 0.3050 - val_auc: 0.3283 - val_loss: 0.3856 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7726 - auc: 0.8555 - loss: 0.0304 - val_accuracy: 0.2700 - val_auc: 0.3122 - val_loss: 0.6706 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.7983 - auc: 0.8895 - loss: 0.0273 - val_accuracy: 0.3300 - val_auc: 0.3637 - val_loss: 0.2120 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8385 - auc: 0.9128 - loss: 0.0251 - val_accuracy: 0.3100 - val_auc: 0.3205 - val_loss: 0.3067 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9063 - auc: 0.9739 - loss: 0.0142 - val_accuracy: 0.3150 - val_auc: 0.3082 - val_loss: 0.2243 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.8208 - auc: 0.9205 - loss: 0.0233 - val_accuracy: 0.3800 - val_auc: 0.3645 - val_loss: 0.1796 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.8962 - auc: 0.9665 - loss: 0.0158 - val_accuracy: 0.6850 - val_auc: 0.7467 - val_loss: 0.1283 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8494 - auc: 0.9187 - loss: 0.0242 - val_accuracy: 0.7250 - val_auc: 0.8374 - val_loss: 0.0438 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9226 - auc: 0.9710 - loss: 0.0153 - val_accuracy: 0.7550 - val_auc: 0.8199 - val_loss: 0.1106 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9164 - auc: 0.9762 - loss: 0.0131 - val_accuracy: 0.4250 - val_auc: 0.5071 - val_loss: 0.2289 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9362 - auc: 0.9819 - loss: 0.0116 - val_accuracy: 0.7300 - val_auc: 0.7421 - val_loss: 0.6877 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9511 - auc: 0.9886 - loss: 0.0109 - val_accuracy: 0.6000 - val_auc: 0.6606 - val_loss: 0.0947 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9824 - auc: 0.9975 - loss: 0.0042 - val_accuracy: 0.7050 - val_auc: 0.8152 - val_loss: 0.0574 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9306 - auc: 0.9846 - loss: 0.0107 - val_accuracy: 0.7300 - val_auc: 0.8230 - val_loss: 0.1028 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9301 - auc: 0.9844 - loss: 0.0108 - val_accuracy: 0.7500 - val_auc: 0.8074 - val_loss: 0.0444 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9659 - auc: 0.9955 - loss: 0.0059 - val_accuracy: 0.6750 - val_auc: 0.7728 - val_loss: 0.0661 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9590 - auc: 0.9922 - loss: 0.0076 - val_accuracy: 0.7500 - val_auc: 0.7912 - val_loss: 0.2560 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9669 - auc: 0.9913 - loss: 0.0076 - val_accuracy: 0.6500 - val_auc: 0.7126 - val_loss: 0.1181 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9776 - auc: 0.9961 - loss: 0.0052 - val_accuracy: 0.5250 - val_auc: 0.5654 - val_loss: 0.1558 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9739 - auc: 0.9971 - loss: 0.0048 - val_accuracy: 0.7850 - val_auc: 0.8783 - val_loss: 0.0796 - learning_rate: 0.0010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9718 - auc: 0.9902 - loss: 0.0080 - val_accuracy: 0.7500 - val_auc: 0.7947 - val_loss: 0.0565 - learning_rate: 0.0010
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9546 - auc: 0.9852 - loss: 0.0100 - val_accuracy: 0.7800 - val_auc: 0.8837 - val_loss: 0.0430 - learning_rate: 0.0010
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9880 - auc: 0.9992 - loss: 0.0030 - val_accuracy: 0.7400 - val_auc: 0.8551 - val_loss: 0.0910 - learning_rate: 0.0010
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9718 - auc: 0.9946 - loss: 0.0063 - val_accuracy: 0.7500 - val_auc: 0.8438 - val_loss: 0.1963 - learning_rate: 0.0010
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9614 - auc: 0.9897 - loss: 0.0084 - val_accuracy: 0.7950 - val_auc: 0.8689 - val_loss: 0.0411 - learning_rate: 0.0010
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9635 - auc: 0.9959 - loss: 0.0052 - val_accuracy: 0.4850 - val_auc: 0.5415 - val_loss: 0.2198 - learning_rate: 0.0010
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9842 - auc: 0.9986 - loss: 0.0029 - val_accuracy: 0.7400 - val_auc: 0.7946 - val_loss: 0.0963 - learning_rate: 0.0010
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9934 - auc: 0.9999 - loss: 0.0011 - val_accuracy: 0.8000 - val_auc: 0.8713 - val_loss: 0.0647 - learning_rate: 0.0010
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9917 - auc: 0.9997 - loss: 0.0018 - val_accuracy: 0.7600 - val_auc: 0.8105 - val_loss: 0.0931 - learning_rate: 0.0010
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9854 - auc: 0.9979 - loss: 0.0038 - val_accuracy: 0.7550 - val_auc: 0.8480 - val_loss: 0.0646 - learning_rate: 0.0010
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9868 - auc: 0.9988 - loss: 0.0030 - val_accuracy: 0.7750 - val_auc: 0.8618 - val_loss: 0.0816 - learning_rate: 0.0010
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9767 - auc: 0.9984 - loss: 0.0035 - val_accuracy: 0.8000 - val_auc: 0.8908 - val_loss: 0.0654 - learning_rate: 0.0010
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9910 - auc: 0.9995 - loss: 0.0018 - val_accuracy: 0.7050 - val_auc: 0.7542 - val_loss: 0.1178 - learning_rate: 0.0010
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9740 - auc: 0.9980 - loss: 0.0038 - val_accuracy: 0.8300 - val_auc: 0.9087 - val_loss: 0.0523 - learning_rate: 0.0010
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9823 - auc: 0.9979 - loss: 0.0034 - val_accuracy: 0.5100 - val_auc: 0.5501 - val_loss: 0.2014 - learning_rate: 0.0010
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9550 - auc: 0.9876 - loss: 0.0100 - val_accuracy: 0.7300 - val_auc: 0.7436 - val_loss: 0.7961 - learning_rate: 0.0010
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9407 - auc: 0.9819 - loss: 0.0113 - val_accuracy: 0.7350 - val_auc: 0.7807 - val_loss: 0.5077 - learning_rate: 0.0010
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9957 - auc: 0.9999 - loss: 0.0018 - val_accuracy: 0.7600 - val_auc: 0.8598 - val_loss: 0.2434 - learning_rate: 0.0010
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9964 - auc: 0.9997 - loss: 0.0014 - val_accuracy: 0.8050 - val_auc: 0.8583 - val_loss: 0.1616 - learning_rate: 0.0010
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9903 - auc: 0.9995 - loss: 0.0020 - val_accuracy: 0.8100 - val_auc: 0.8623 - val_loss: 0.0934 - learning_rate: 0.0010
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9492 - auc: 0.9871 - loss: 0.0113 - val_accuracy: 0.7650 - val_auc: 0.8655 - val_loss: 0.0544 - learning_rate: 0.0010
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9824 - auc: 0.9964 - loss: 0.0048 - val_accuracy: 0.7500 - val_auc: 0.8638 - val_loss: 0.0654 - learning_rate: 0.0010
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9980 - auc: 1.0000 - loss: 9.5084e-04 - val_accuracy: 0.7250 - val_auc: 0.7907 - val_loss: 0.0990 - learning_rate: 0.0010
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9854 - auc: 0.9973 - loss: 0.0039 - val_accuracy: 0.7300 - val_auc: 0.7596 - val_loss: 0.5134 - learning_rate: 0.0010
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9445 - auc: 0.9841 - loss: 0.0107 - val_accuracy: 0.7300 - val_auc: 0.7597 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 48/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9895 - auc: 0.9959 - loss: 0.0047 - val_accuracy: 0.7100 - val_auc: 0.8167 - val_loss: 0.1840 - learning_rate: 0.0010
# Epoch 49/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9893 - auc: 0.9986 - loss: 0.0027 - val_accuracy: 0.7300 - val_auc: 0.8099 - val_loss: 0.0737 - learning_rate: 0.0010
# Epoch 50/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9902 - auc: 0.9995 - loss: 0.0020 - val_accuracy: 0.7200 - val_auc: 0.8187 - val_loss: 0.0957 - learning_rate: 0.0010
# Epoch 51/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9918 - auc: 0.9991 - loss: 0.0022 - val_accuracy: 0.7750 - val_auc: 0.8629 - val_loss: 0.0747 - learning_rate: 0.0010
# Epoch 52/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9778 - auc: 0.9989 - loss: 0.0027 - val_accuracy: 0.7750 - val_auc: 0.8419 - val_loss: 0.0617 - learning_rate: 0.0010
# Epoch 53/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9905 - auc: 0.9996 - loss: 0.0016 - val_accuracy: 0.7350 - val_auc: 0.7866 - val_loss: 0.0907 - learning_rate: 5.0000e-04
# Epoch 54/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 5.0043e-04 - val_accuracy: 0.7600 - val_auc: 0.8518 - val_loss: 0.0793 - learning_rate: 5.0000e-04
# Epoch 55/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.9029e-04 - val_accuracy: 0.7800 - val_auc: 0.8563 - val_loss: 0.0842 - learning_rate: 5.0000e-04
# Epoch 56/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 1.5406e-04 - val_accuracy: 0.7950 - val_auc: 0.8669 - val_loss: 0.0841 - learning_rate: 5.0000e-04
# Epoch 57/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 5.7535e-05 - val_accuracy: 0.7850 - val_auc: 0.8754 - val_loss: 0.0856 - learning_rate: 5.0000e-04
# Epoch 58/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.4716e-05 - val_accuracy: 0.7800 - val_auc: 0.8772 - val_loss: 0.0880 - learning_rate: 5.0000e-04
# Epoch 59/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.1766e-04 - val_accuracy: 0.7750 - val_auc: 0.8803 - val_loss: 0.0895 - learning_rate: 5.0000e-04
# Epoch 60/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.4784e-05 - val_accuracy: 0.7950 - val_auc: 0.8799 - val_loss: 0.0920 - learning_rate: 5.0000e-04
# Epoch 61/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 7.2775e-04 - val_accuracy: 0.7750 - val_auc: 0.8616 - val_loss: 0.0906 - learning_rate: 5.0000e-04
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 246s 4s/step - accuracy: 0.6821 - auc: 0.6891 - loss: 11.0234 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.6926 - auc: 0.6926 - loss: 10.9177 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6912 - auc: 0.6912 - loss: 10.9453 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6693 - auc: 0.6693 - loss: 11.3599 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6905 - auc: 0.6905 - loss: 10.9590 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6903 - auc: 0.6903 - loss: 10.9624 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6758 - auc: 0.6758 - loss: 11.2372 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6882 - auc: 0.6882 - loss: 11.0019 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7066 - auc: 0.7066 - loss: 10.6540 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6727 - auc: 0.6727 - loss: 11.2958 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7166 - auc: 0.7166 - loss: 10.4630 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6878 - auc: 0.6878 - loss: 11.0099 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6709 - auc: 0.6709 - loss: 11.3286 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6721 - auc: 0.6721 - loss: 11.3066 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7034 - auc: 0.7034 - loss: 10.7160 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6858 - auc: 0.6858 - loss: 11.0484 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6832 - auc: 0.6832 - loss: 11.0972 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6693 - auc: 0.6693 - loss: 11.3616 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6962 - auc: 0.6962 - loss: 10.8509 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6515 - auc: 0.6515 - loss: 11.6974 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6809 - auc: 0.6809 - loss: 11.1407 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6740 - auc: 0.6740 - loss: 11.2711 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6868 - auc: 0.6868 - loss: 11.0299 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6912 - auc: 0.6912 - loss: 10.9456 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7100 - auc: 0.7100 - loss: 10.5894 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6975 - auc: 0.6975 - loss: 10.8253 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 246s 4s/step - accuracy: 0.5463 - auc: 0.5496 - loss: 0.9098 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 1230.0231 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6230 - auc: 0.6645 - loss: 0.6566 - val_accuracy: 0.3150 - val_auc: 0.2779 - val_loss: 13.6578 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.7528 - auc: 0.8267 - loss: 0.5226 - val_accuracy: 0.7200 - val_auc: 0.7426 - val_loss: 4.3813 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.7480 - auc: 0.8243 - loss: 0.4921 - val_accuracy: 0.7050 - val_auc: 0.7819 - val_loss: 1.1337 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7856 - auc: 0.8714 - loss: 0.4644 - val_accuracy: 0.7350 - val_auc: 0.7739 - val_loss: 1.4529 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8119 - auc: 0.8823 - loss: 0.4252 - val_accuracy: 0.3950 - val_auc: 0.4248 - val_loss: 0.8799 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8582 - auc: 0.9345 - loss: 0.3445 - val_accuracy: 0.6800 - val_auc: 0.7136 - val_loss: 0.8996 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8593 - auc: 0.9249 - loss: 0.3729 - val_accuracy: 0.6950 - val_auc: 0.7369 - val_loss: 1.0805 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8732 - auc: 0.9476 - loss: 0.3055 - val_accuracy: 0.5250 - val_auc: 0.5549 - val_loss: 1.6001 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9068 - auc: 0.9624 - loss: 0.2267 - val_accuracy: 0.4200 - val_auc: 0.4911 - val_loss: 1.2854 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8613 - auc: 0.9443 - loss: 0.2691 - val_accuracy: 0.5950 - val_auc: 0.6292 - val_loss: 1.1026 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8831 - auc: 0.9589 - loss: 0.2323 - val_accuracy: 0.6300 - val_auc: 0.7190 - val_loss: 0.8742 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9199 - auc: 0.9710 - loss: 0.1945 - val_accuracy: 0.7700 - val_auc: 0.8132 - val_loss: 1.1275 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8917 - auc: 0.9674 - loss: 0.2438 - val_accuracy: 0.5900 - val_auc: 0.5982 - val_loss: 1.8914 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9476 - auc: 0.9846 - loss: 0.1454 - val_accuracy: 0.5600 - val_auc: 0.5850 - val_loss: 1.3580 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9334 - auc: 0.9752 - loss: 0.1588 - val_accuracy: 0.4600 - val_auc: 0.4726 - val_loss: 3.5127 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9470 - auc: 0.9798 - loss: 0.1374 - val_accuracy: 0.7500 - val_auc: 0.8109 - val_loss: 0.9457 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9248 - auc: 0.9737 - loss: 0.1619 - val_accuracy: 0.6400 - val_auc: 0.6665 - val_loss: 1.3570 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9017 - auc: 0.9665 - loss: 0.2125 - val_accuracy: 0.7000 - val_auc: 0.7225 - val_loss: 1.4288 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9219 - auc: 0.9757 - loss: 0.1545 - val_accuracy: 0.6800 - val_auc: 0.7181 - val_loss: 1.1823 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9661 - auc: 0.9893 - loss: 0.0948 - val_accuracy: 0.7350 - val_auc: 0.7961 - val_loss: 0.8290 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9755 - auc: 0.9944 - loss: 0.0576 - val_accuracy: 0.7150 - val_auc: 0.7776 - val_loss: 0.9201 - learning_rate: 0.0010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9423 - auc: 0.9704 - loss: 0.1786 - val_accuracy: 0.7550 - val_auc: 0.8276 - val_loss: 1.4531 - learning_rate: 0.0010
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9589 - auc: 0.9901 - loss: 0.1263 - val_accuracy: 0.6100 - val_auc: 0.6683 - val_loss: 1.1814 - learning_rate: 0.0010
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9801 - auc: 0.9945 - loss: 0.0554 - val_accuracy: 0.7250 - val_auc: 0.7559 - val_loss: 1.5020 - learning_rate: 0.0010
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9777 - auc: 0.9882 - loss: 0.0697 - val_accuracy: 0.7100 - val_auc: 0.7359 - val_loss: 1.2149 - learning_rate: 0.0010
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9725 - auc: 0.9911 - loss: 0.0803 - val_accuracy: 0.8350 - val_auc: 0.8661 - val_loss: 0.9279 - learning_rate: 0.0010
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9821 - auc: 0.9982 - loss: 0.0489 - val_accuracy: 0.7900 - val_auc: 0.8329 - val_loss: 1.4100 - learning_rate: 0.0010
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9745 - auc: 0.9955 - loss: 0.0533 - val_accuracy: 0.8250 - val_auc: 0.8496 - val_loss: 0.9084 - learning_rate: 0.0010
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9899 - auc: 0.9948 - loss: 0.0347 - val_accuracy: 0.8000 - val_auc: 0.8567 - val_loss: 0.7492 - learning_rate: 0.0010
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9744 - auc: 0.9916 - loss: 0.0740 - val_accuracy: 0.7700 - val_auc: 0.8292 - val_loss: 0.8727 - learning_rate: 0.0010
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9728 - auc: 0.9956 - loss: 0.0676 - val_accuracy: 0.7950 - val_auc: 0.8146 - val_loss: 1.1927 - learning_rate: 0.0010
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9639 - auc: 0.9936 - loss: 0.0828 - val_accuracy: 0.6550 - val_auc: 0.6629 - val_loss: 1.2550 - learning_rate: 0.0010
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9574 - auc: 0.9931 - loss: 0.0719 - val_accuracy: 0.7300 - val_auc: 0.7751 - val_loss: 1.2879 - learning_rate: 0.0010
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9764 - auc: 0.9935 - loss: 0.0611 - val_accuracy: 0.7500 - val_auc: 0.7663 - val_loss: 1.3992 - learning_rate: 0.0010
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9754 - auc: 0.9895 - loss: 0.0562 - val_accuracy: 0.7300 - val_auc: 0.7513 - val_loss: 1.8267 - learning_rate: 0.0010
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9675 - auc: 0.9866 - loss: 0.0882 - val_accuracy: 0.7550 - val_auc: 0.8121 - val_loss: 1.1544 - learning_rate: 0.0010
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9599 - auc: 0.9937 - loss: 0.1074 - val_accuracy: 0.7950 - val_auc: 0.8049 - val_loss: 1.2688 - learning_rate: 0.0010
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9762 - auc: 0.9878 - loss: 0.0764 - val_accuracy: 0.7650 - val_auc: 0.8474 - val_loss: 0.7364 - learning_rate: 0.0010
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9895 - auc: 0.9980 - loss: 0.0312 - val_accuracy: 0.5500 - val_auc: 0.5528 - val_loss: 3.3075 - learning_rate: 0.0010
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9921 - auc: 0.9934 - loss: 0.0337 - val_accuracy: 0.7800 - val_auc: 0.8092 - val_loss: 0.9807 - learning_rate: 0.0010
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9814 - auc: 0.9926 - loss: 0.0526 - val_accuracy: 0.8200 - val_auc: 0.8456 - val_loss: 0.8591 - learning_rate: 0.0010
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9801 - auc: 0.9942 - loss: 0.0609 - val_accuracy: 0.7150 - val_auc: 0.7299 - val_loss: 1.7001 - learning_rate: 0.0010
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9914 - auc: 0.9983 - loss: 0.0321 - val_accuracy: 0.7550 - val_auc: 0.8297 - val_loss: 1.0481 - learning_rate: 0.0010
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9827 - auc: 0.9940 - loss: 0.0425 - val_accuracy: 0.7750 - val_auc: 0.8357 - val_loss: 0.7666 - learning_rate: 0.0010
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9986 - auc: 0.9999 - loss: 0.0168 - val_accuracy: 0.7850 - val_auc: 0.8431 - val_loss: 0.8501 - learning_rate: 0.0010
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.0069 - val_accuracy: 0.8150 - val_auc: 0.8323 - val_loss: 0.9446 - learning_rate: 0.0010
# Epoch 48/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0023 - val_accuracy: 0.8050 - val_auc: 0.8210 - val_loss: 1.0215 - learning_rate: 0.0010
# Epoch 49/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0013 - val_accuracy: 0.8000 - val_auc: 0.8251 - val_loss: 1.0676 - learning_rate: 0.0010
# Epoch 50/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.0800e-04 - val_accuracy: 0.8000 - val_auc: 0.8375 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 51/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.7289e-04 - val_accuracy: 0.8050 - val_auc: 0.8373 - val_loss: 1.1641 - learning_rate: 0.0010
# Epoch 52/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.4812e-04 - val_accuracy: 0.7800 - val_auc: 0.8081 - val_loss: 1.3185 - learning_rate: 0.0010
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 388ms/step - accuracy: 0.3064 - auc: 0.3206 - loss: 0.0441 - val_accuracy: 0.2850 - val_auc: 0.4638 - val_loss: 0.0435 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5344 - auc: 0.5468 - loss: 0.0433 - val_accuracy: 0.7300 - val_auc: 0.7448 - val_loss: 0.0424 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6671 - auc: 0.6669 - loss: 0.0426 - val_accuracy: 0.7300 - val_auc: 0.7567 - val_loss: 0.0417 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6496 - auc: 0.6742 - loss: 0.0421 - val_accuracy: 0.7300 - val_auc: 0.7260 - val_loss: 0.0410 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6960 - auc: 0.6934 - loss: 0.0412 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0404 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6853 - auc: 0.6871 - loss: 0.0410 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0400 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6704 - auc: 0.6747 - loss: 0.0410 - val_accuracy: 0.7300 - val_auc: 0.7325 - val_loss: 0.0396 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6747 - auc: 0.6831 - loss: 0.0407 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0393 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6697 - auc: 0.6754 - loss: 0.0406 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0391 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7038 - auc: 0.7017 - loss: 0.0397 - val_accuracy: 0.7300 - val_auc: 0.7287 - val_loss: 0.0388 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6926 - auc: 0.6926 - loss: 0.0398 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0387 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6898 - auc: 0.6896 - loss: 0.0398 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0385 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6738 - auc: 0.6738 - loss: 0.0401 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0384 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6782 - auc: 0.6782 - loss: 0.0399 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0383 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6851 - auc: 0.6834 - loss: 0.0397 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0382 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6908 - auc: 0.6908 - loss: 0.0394 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0381 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6828 - auc: 0.6828 - loss: 0.0397 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6892 - auc: 0.6882 - loss: 0.0394 - val_accuracy: 0.7300 - val_auc: 0.7017 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6896 - auc: 0.6813 - loss: 0.0394 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0379 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6893 - auc: 0.6893 - loss: 0.0394 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0378 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6969 - auc: 0.6969 - loss: 0.0391 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0378 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7111 - auc: 0.7111 - loss: 0.0385 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0378 - learning_rate: 0.0010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6952 - auc: 0.6857 - loss: 0.0391 - val_accuracy: 0.7300 - val_auc: 0.7152 - val_loss: 0.0377 - learning_rate: 0.0010
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6749 - auc: 0.6692 - loss: 0.0398 - val_accuracy: 0.7300 - val_auc: 0.7287 - val_loss: 0.0377 - learning_rate: 0.0010
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7057 - auc: 0.7040 - loss: 0.0386 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0377 - learning_rate: 0.0010
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6743 - auc: 0.6743 - loss: 0.0399 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0377 - learning_rate: 0.0010
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6781 - auc: 0.6781 - loss: 0.0397 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0376 - learning_rate: 0.0010
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6854 - auc: 0.6854 - loss: 0.0394 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 0.0376 - learning_rate: 0.0010
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 256ms/step - accuracy: 0.7060 - auc: 0.6852 - loss: 11.4407 - val_accuracy: 0.7300 - val_auc: 0.6856 - val_loss: 10.0789 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6830 - auc: 0.6673 - loss: 10.7669 - val_accuracy: 0.7300 - val_auc: 0.6940 - val_loss: 9.8614 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6669 - auc: 0.6382 - loss: 10.9081 - val_accuracy: 0.7300 - val_auc: 0.6998 - val_loss: 9.8625 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6888 - auc: 0.6461 - loss: 10.6663 - val_accuracy: 0.7300 - val_auc: 0.6984 - val_loss: 9.8415 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6732 - auc: 0.6416 - loss: 10.8405 - val_accuracy: 0.7300 - val_auc: 0.7082 - val_loss: 9.8568 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6790 - auc: 0.6488 - loss: 10.7697 - val_accuracy: 0.7300 - val_auc: 0.7063 - val_loss: 9.8381 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6754 - auc: 0.6512 - loss: 10.8095 - val_accuracy: 0.7300 - val_auc: 0.7065 - val_loss: 9.8666 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6897 - auc: 0.6645 - loss: 10.6476 - val_accuracy: 0.7300 - val_auc: 0.6958 - val_loss: 9.8597 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6622 - auc: 0.6301 - loss: 10.9525 - val_accuracy: 0.7300 - val_auc: 0.6991 - val_loss: 9.8600 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6613 - auc: 0.6330 - loss: 10.9629 - val_accuracy: 0.7300 - val_auc: 0.7124 - val_loss: 9.8455 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6834 - auc: 0.6652 - loss: 10.7135 - val_accuracy: 0.7300 - val_auc: 0.7081 - val_loss: 9.8459 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6828 - auc: 0.6544 - loss: 10.7219 - val_accuracy: 0.7300 - val_auc: 0.7102 - val_loss: 9.8462 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6881 - auc: 0.6662 - loss: 10.6602 - val_accuracy: 0.7300 - val_auc: 0.7057 - val_loss: 9.8432 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6942 - auc: 0.6638 - loss: 10.5923 - val_accuracy: 0.7300 - val_auc: 0.7075 - val_loss: 9.8407 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6885 - auc: 0.6408 - loss: 10.6616 - val_accuracy: 0.7300 - val_auc: 0.7193 - val_loss: 9.8446 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6830 - auc: 0.6567 - loss: 10.7202 - val_accuracy: 0.7300 - val_auc: 0.7140 - val_loss: 9.8605 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6888 - auc: 0.6590 - loss: 10.6540 - val_accuracy: 0.7300 - val_auc: 0.7047 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6711 - auc: 0.6579 - loss: 10.8509 - val_accuracy: 0.7300 - val_auc: 0.7202 - val_loss: 9.8601 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6927 - auc: 0.6892 - loss: 10.6064 - val_accuracy: 0.7300 - val_auc: 0.7191 - val_loss: 9.8348 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7025 - auc: 0.6776 - loss: 10.4908 - val_accuracy: 0.7300 - val_auc: 0.7119 - val_loss: 9.8485 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6842 - auc: 0.6645 - loss: 10.7024 - val_accuracy: 0.7300 - val_auc: 0.7052 - val_loss: 9.8661 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6940 - auc: 0.6767 - loss: 10.5959 - val_accuracy: 0.7300 - val_auc: 0.7285 - val_loss: 9.8399 - learning_rate: 0.0010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7059 - auc: 0.6825 - loss: 10.4549 - val_accuracy: 0.7300 - val_auc: 0.7273 - val_loss: 9.8414 - learning_rate: 0.0010
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6794 - auc: 0.6554 - loss: 10.7565 - val_accuracy: 0.7300 - val_auc: 0.7140 - val_loss: 9.8631 - learning_rate: 0.0010
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6953 - auc: 0.6808 - loss: 10.5808 - val_accuracy: 0.7300 - val_auc: 0.7278 - val_loss: 9.8518 - learning_rate: 0.0010
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7131 - auc: 0.7015 - loss: 10.3801 - val_accuracy: 0.7300 - val_auc: 0.7260 - val_loss: 9.8417 - learning_rate: 0.0010
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6949 - auc: 0.6887 - loss: 10.5782 - val_accuracy: 0.7300 - val_auc: 0.7318 - val_loss: 9.8557 - learning_rate: 0.0010
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6989 - auc: 0.6889 - loss: 10.5392 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8470 - learning_rate: 0.0010
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6766 - auc: 0.6651 - loss: 10.7878 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8489 - learning_rate: 0.0010
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6686 - auc: 0.6598 - loss: 10.8751 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8591 - learning_rate: 0.0010
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6817 - auc: 0.6774 - loss: 10.7260 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8393 - learning_rate: 0.0010
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7007 - auc: 0.6872 - loss: 10.5134 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8405 - learning_rate: 0.0010
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7209 - auc: 0.7089 - loss: 10.2821 - val_accuracy: 0.7300 - val_auc: 0.7222 - val_loss: 9.8263 - learning_rate: 0.0010
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6872 - auc: 0.6884 - loss: 10.6648 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8571 - learning_rate: 0.0010
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6957 - auc: 0.6955 - loss: 10.5720 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8472 - learning_rate: 0.0010
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6866 - auc: 0.6891 - loss: 10.6716 - val_accuracy: 0.7300 - val_auc: 0.7638 - val_loss: 9.8414 - learning_rate: 0.0010
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6670 - auc: 0.6530 - loss: 10.8974 - val_accuracy: 0.7300 - val_auc: 0.7616 - val_loss: 9.8404 - learning_rate: 0.0010
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6959 - auc: 0.7004 - loss: 10.5662 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8546 - learning_rate: 0.0010
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6610 - auc: 0.6668 - loss: 10.9540 - val_accuracy: 0.7300 - val_auc: 0.7300 - val_loss: 9.8550 - learning_rate: 0.0010
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7118 - auc: 0.6992 - loss: 10.3939 - val_accuracy: 0.7300 - val_auc: 0.7548 - val_loss: 9.8243 - learning_rate: 0.0010
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6944 - auc: 0.6988 - loss: 10.5785 - val_accuracy: 0.7300 - val_auc: 0.7368 - val_loss: 9.8439 - learning_rate: 0.0010
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6929 - auc: 0.6960 - loss: 10.5998 - val_accuracy: 0.7300 - val_auc: 0.7296 - val_loss: 9.8449 - learning_rate: 0.0010
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6744 - auc: 0.6868 - loss: 10.8063 - val_accuracy: 0.7300 - val_auc: 0.7394 - val_loss: 9.8530 - learning_rate: 0.0010
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6811 - auc: 0.6879 - loss: 10.7313 - val_accuracy: 0.7300 - val_auc: 0.7653 - val_loss: 9.8398 - learning_rate: 0.0010
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6723 - auc: 0.6893 - loss: 10.8293 - val_accuracy: 0.7300 - val_auc: 0.7501 - val_loss: 9.8400 - learning_rate: 0.0010
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6845 - auc: 0.6919 - loss: 10.6919 - val_accuracy: 0.7300 - val_auc: 0.7642 - val_loss: 9.8368 - learning_rate: 0.0010
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6973 - auc: 0.7178 - loss: 10.5464 - val_accuracy: 0.7300 - val_auc: 0.7607 - val_loss: 9.8345 - learning_rate: 0.0010
# Epoch 48/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6907 - auc: 0.7062 - loss: 10.6208 - val_accuracy: 0.7300 - val_auc: 0.7629 - val_loss: 9.8445 - learning_rate: 0.0010
# Epoch 49/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6625 - auc: 0.6684 - loss: 10.9356 - val_accuracy: 0.7300 - val_auc: 0.7642 - val_loss: 9.8522 - learning_rate: 0.0010
# Epoch 50/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6705 - auc: 0.6832 - loss: 10.8471 - val_accuracy: 0.7300 - val_auc: 0.7577 - val_loss: 9.8348 - learning_rate: 0.0010
# Epoch 51/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6685 - auc: 0.6753 - loss: 10.8750 - val_accuracy: 0.7300 - val_auc: 0.7628 - val_loss: 9.8287 - learning_rate: 0.0010
# Epoch 52/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6847 - auc: 0.7024 - loss: 10.6883 - val_accuracy: 0.7300 - val_auc: 0.7600 - val_loss: 9.8328 - learning_rate: 0.0010
# Epoch 53/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6953 - auc: 0.7222 - loss: 10.5658 - val_accuracy: 0.7300 - val_auc: 0.7686 - val_loss: 9.8310 - learning_rate: 0.0010
# Epoch 54/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6900 - auc: 0.7058 - loss: 10.6252 - val_accuracy: 0.7300 - val_auc: 0.7731 - val_loss: 9.8551 - learning_rate: 0.0010
# Epoch 55/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6779 - auc: 0.7018 - loss: 10.7608 - val_accuracy: 0.7300 - val_auc: 0.7699 - val_loss: 9.8331 - learning_rate: 0.0010
# Epoch 56/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6902 - auc: 0.7061 - loss: 10.6267 - val_accuracy: 0.7300 - val_auc: 0.7696 - val_loss: 9.8233 - learning_rate: 0.0010
# Epoch 57/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6766 - auc: 0.6995 - loss: 10.7739 - val_accuracy: 0.7300 - val_auc: 0.7795 - val_loss: 9.8571 - learning_rate: 0.0010
# Epoch 58/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6814 - auc: 0.7053 - loss: 10.7183 - val_accuracy: 0.7300 - val_auc: 0.7707 - val_loss: 9.8268 - learning_rate: 0.0010
# Epoch 59/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6706 - auc: 0.6980 - loss: 10.8426 - val_accuracy: 0.7300 - val_auc: 0.7693 - val_loss: 9.8425 - learning_rate: 0.0010
# Epoch 60/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6905 - auc: 0.7113 - loss: 10.6189 - val_accuracy: 0.7300 - val_auc: 0.7779 - val_loss: 9.8315 - learning_rate: 0.0010
# Epoch 61/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6930 - auc: 0.7385 - loss: 10.5794 - val_accuracy: 0.7300 - val_auc: 0.7663 - val_loss: 9.8335 - learning_rate: 0.0010
# Epoch 62/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6878 - auc: 0.6946 - loss: 10.6552 - val_accuracy: 0.7300 - val_auc: 0.7869 - val_loss: 9.8374 - learning_rate: 0.0010
# Epoch 63/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6753 - auc: 0.7200 - loss: 10.7757 - val_accuracy: 0.7300 - val_auc: 0.7735 - val_loss: 9.8297 - learning_rate: 0.0010
# Epoch 64/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6720 - auc: 0.6913 - loss: 10.8244 - val_accuracy: 0.7300 - val_auc: 0.7710 - val_loss: 9.8291 - learning_rate: 0.0010
# Epoch 65/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6882 - auc: 0.7031 - loss: 10.6425 - val_accuracy: 0.7300 - val_auc: 0.7721 - val_loss: 9.8212 - learning_rate: 0.0010
# Epoch 66/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6917 - auc: 0.7119 - loss: 10.5995 - val_accuracy: 0.7300 - val_auc: 0.7731 - val_loss: 9.8258 - learning_rate: 0.0010
# Epoch 67/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6690 - auc: 0.6817 - loss: 10.8548 - val_accuracy: 0.7300 - val_auc: 0.7727 - val_loss: 9.8339 - learning_rate: 0.0010
# Epoch 68/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6855 - auc: 0.7146 - loss: 10.6623 - val_accuracy: 0.7300 - val_auc: 0.7739 - val_loss: 9.8217 - learning_rate: 0.0010
# Epoch 69/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6923 - auc: 0.7315 - loss: 10.5820 - val_accuracy: 0.7300 - val_auc: 0.7750 - val_loss: 9.8091 - learning_rate: 0.0010
# Epoch 70/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6959 - auc: 0.7186 - loss: 10.5491 - val_accuracy: 0.7300 - val_auc: 0.7767 - val_loss: 9.8519 - learning_rate: 0.0010
# Epoch 71/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6656 - auc: 0.7016 - loss: 10.8685 - val_accuracy: 0.7300 - val_auc: 0.7737 - val_loss: 9.8064 - learning_rate: 0.0010
# Epoch 72/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6755 - auc: 0.7091 - loss: 10.7695 - val_accuracy: 0.7300 - val_auc: 0.7731 - val_loss: 9.7941 - learning_rate: 0.0010
# Epoch 73/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6844 - auc: 0.7157 - loss: 10.6655 - val_accuracy: 0.7300 - val_auc: 0.7771 - val_loss: 9.8382 - learning_rate: 0.0010
# Epoch 74/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6662 - auc: 0.7144 - loss: 10.8498 - val_accuracy: 0.7300 - val_auc: 0.7664 - val_loss: 9.7698 - learning_rate: 0.0010
# Epoch 75/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6866 - auc: 0.7054 - loss: 10.6551 - val_accuracy: 0.7300 - val_auc: 0.7855 - val_loss: 9.8477 - learning_rate: 0.0010
# Epoch 76/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6693 - auc: 0.7076 - loss: 10.8210 - val_accuracy: 0.7300 - val_auc: 0.7762 - val_loss: 9.7962 - learning_rate: 0.0010
# Epoch 77/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6972 - auc: 0.7296 - loss: 10.5177 - val_accuracy: 0.7300 - val_auc: 0.7757 - val_loss: 9.7923 - learning_rate: 0.0010
# Epoch 78/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6790 - auc: 0.7185 - loss: 10.7119 - val_accuracy: 0.7300 - val_auc: 0.7768 - val_loss: 9.8204 - learning_rate: 0.0010
# Epoch 79/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7028 - auc: 0.7471 - loss: 10.4377 - val_accuracy: 0.7300 - val_auc: 0.7745 - val_loss: 9.7961 - learning_rate: 0.0010
# Epoch 80/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6832 - auc: 0.7243 - loss: 10.6497 - val_accuracy: 0.7300 - val_auc: 0.7765 - val_loss: 9.7965 - learning_rate: 0.0010
# Epoch 81/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6589 - auc: 0.6964 - loss: 10.9069 - val_accuracy: 0.7300 - val_auc: 0.7709 - val_loss: 9.7402 - learning_rate: 0.0010
# Epoch 82/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6960 - auc: 0.7239 - loss: 10.5197 - val_accuracy: 0.7300 - val_auc: 0.7812 - val_loss: 9.7717 - learning_rate: 0.0010
# Epoch 83/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6819 - auc: 0.7170 - loss: 10.6737 - val_accuracy: 0.7300 - val_auc: 0.7789 - val_loss: 9.7459 - learning_rate: 0.0010
# Epoch 84/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6678 - auc: 0.7159 - loss: 10.7916 - val_accuracy: 0.7300 - val_auc: 0.7714 - val_loss: 9.7181 - learning_rate: 0.0010
# Epoch 85/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6968 - auc: 0.7522 - loss: 10.4408 - val_accuracy: 0.7300 - val_auc: 0.7847 - val_loss: 9.8386 - learning_rate: 0.0010
# Epoch 86/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7013 - auc: 0.7307 - loss: 10.4825 - val_accuracy: 0.7300 - val_auc: 0.7820 - val_loss: 9.7939 - learning_rate: 0.0010
# Epoch 87/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6622 - auc: 0.7039 - loss: 10.8281 - val_accuracy: 0.7300 - val_auc: 0.7773 - val_loss: 9.6987 - learning_rate: 0.0010
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 175ms/step - accuracy: 0.3396 - auc: 0.5000 - loss: 0.7069 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3179 - auc: 0.5000 - loss: 0.6942 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3166 - auc: 0.5000 - loss: 0.6934 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3330 - auc: 0.5000 - loss: 0.7030 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3802 - auc: 0.5000 - loss: 0.6846 - val_accuracy: 0.7200 - val_auc: 0.5000 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4492 - auc: 0.5000 - loss: 0.6984 - val_accuracy: 0.6100 - val_auc: 0.5000 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3637 - auc: 0.5000 - loss: 0.6967 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3187 - auc: 0.5000 - loss: 0.6909 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6934 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3174 - auc: 0.5000 - loss: 0.6939 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6934 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3132 - auc: 0.5000 - loss: 0.6914 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6933 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3189 - auc: 0.5000 - loss: 0.6947 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3276 - auc: 0.4959 - loss: 0.6998 - val_accuracy: 0.2700 - val_auc: 0.4851 - val_loss: 0.6939 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3171 - auc: 0.5046 - loss: 0.6936 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3043 - auc: 0.5000 - loss: 0.6853 - val_accuracy: 0.2800 - val_auc: 0.5000 - val_loss: 0.6933 - learning_rate: 0.0010
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4166 - auc: 0.5000 - loss: 0.6731 - val_accuracy: 0.7150 - val_auc: 0.5000 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6021 - auc: 0.5000 - loss: 0.6807 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3257 - auc: 0.4947 - loss: 0.6987 - val_accuracy: 0.2700 - val_auc: 0.4762 - val_loss: 0.6941 - learning_rate: 0.0010
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3449 - auc: 0.3950 - loss: 0.7099 - val_accuracy: 0.2700 - val_auc: 0.2700 - val_loss: 0.6946 - learning_rate: 0.0010
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3206 - auc: 0.3732 - loss: 0.6957 - val_accuracy: 0.2700 - val_auc: 0.4674 - val_loss: 0.6941 - learning_rate: 0.0010
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3265 - auc: 0.4846 - loss: 0.6991 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3075 - auc: 0.4998 - loss: 0.6853 - val_accuracy: 0.2700 - val_auc: 0.4901 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3238 - auc: 0.4944 - loss: 0.6976 - val_accuracy: 0.2700 - val_auc: 0.4851 - val_loss: 0.6938 - learning_rate: 0.0010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3232 - auc: 0.4901 - loss: 0.6972 - val_accuracy: 0.2700 - val_auc: 0.4852 - val_loss: 0.6939 - learning_rate: 0.0010
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3154 - auc: 0.5007 - loss: 0.6926 - val_accuracy: 0.2700 - val_auc: 0.5000 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3193 - auc: 0.5031 - loss: 0.6949 - val_accuracy: 0.2700 - val_auc: 0.4851 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3284 - auc: 0.4961 - loss: 0.7002 - val_accuracy: 0.2700 - val_auc: 0.4226 - val_loss: 0.6941 - learning_rate: 0.0010

# %%
# 1. Predict and store DenseNet using Focal Loss
densenet_focal_preds_prob = densenet_focal.predict(test_data)
densenet_focal_preds = np.argmax(densenet_focal_preds_prob, axis=1)

# 2. Predict and store DenseNet using APLLoss
densenet_cce_preds_prob = densenet_cce.predict(test_data)
densenet_cce_preds = np.argmax(densenet_cce_preds_prob, axis=1)

# 3. Predict and store DenseNet using Binary Cross-Entropy Loss
densenet_bce_preds_prob = densenet_bce.predict(test_data)
densenet_bce_preds = np.argmax(densenet_bce_preds_prob, axis=1)

# 4. Predict and store CNN using Focal Loss
cnn_focal_preds_prob = cnn_focal.predict(test_data)
cnn_focal_preds = np.argmax(cnn_focal_preds_prob, axis=1)

# 5. Predict and store CNN using APLLoss
cnn_cce_preds_prob = cnn_cce.predict(test_data)
cnn_cce_preds = np.argmax(cnn_cce_preds_prob, axis=1)

# 6. Predict and store CNN using Binary Cross-Entropy Loss
cnn_bce_preds_prob = cnn_bce.predict(test_data)
cnn_bce_preds = np.argmax(cnn_bce_preds_prob, axis=1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x785de6f3dd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x785c63ecf010> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step

# %% [markdown]
# ## Plot AUC Curves

# %%
# Plot AUC curves
plt.figure(figsize=(10, 8))

# DenseNet models
plt.plot(history_densenet_focal.history['val_auc'], label='DenseNet FocalLoss')
plt.plot(history_densenet_cce.history['val_auc'], label='DenseNet Categorical cross-entropy')
plt.plot(history_densenet_bce.history['val_auc'], label='DenseNet Binary Cross-Entropy')

# CNN models
plt.plot(history_cnn_focal.history['val_auc'], label='CNN FocalLoss')
plt.plot(history_cnn_cce.history['val_auc'], label='CNN Categorical cross-entropy')
plt.plot(history_cnn_bce.history['val_auc'], label='CNN Binary Cross-Entropy')

# Plot settings
plt.title('AUC Curves of Models')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Initialize plot
plt.figure(figsize=(10, 8))

# Compute ROC and AUC for each model
models = [densenet_focal, densenet_apl, densenet_bce, cnn_focal, cnn_apl, cnn_bce]
model_names = ['DenseNet FocalLoss', 'DenseNet Categorical cross-entropy', 'DenseNet Binary Cross-Entropy',
               'CNN FocalLoss', 'CNN Categorical cross-entropy', 'CNN Binary Cross-Entropy']
colors = ['blue', 'green', 'orange', 'purple', 'brown', 'red']

for model, name, color in zip(models, model_names, colors):
    # Predict probabilities for the test data
    preds = model.predict(test_data)

    # Get true labels (convert one-hot to 1D if necessary)
    # Check if test_targets is already 1D, if not then convert
    if len(test_targets.shape) > 1:
        test_targets_1d = np.argmax(test_targets, axis=1)
    else:
        test_targets_1d = test_targets

    # Compute ROC curve and AUC for each model
    fpr, tpr, _ = roc_curve(test_targets_1d, preds[:, 1])
    auc_value = auc(fpr, tpr)

    # Plot the ROC curve
    plt.plot(fpr, tpr, color=color, label=f'{name} (AUC = {auc_value:.3f})')

# Plot diagonal line for random classifier
plt.plot([0, 1], [0, 1], 'r--', label='Random Classifier')

# Plot settings
plt.title('ROC Curves of Models')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ## Classification Report and CSV Metrics

# %%
# Evaluate models on the test set
def evaluate_model(model, test_data, test_targets_onehot, model_name):
    preds = model.predict(test_data)
    preds_class = np.argmax(preds, axis=1)

    # Convert one-hot encoded test targets back to 1D labels
    test_targets = np.argmax(test_targets_onehot, axis=1)

    # Compute metrics
    report = classification_report(test_targets, preds_class, output_dict=True)
    auc = roc_auc_score(test_targets_onehot, preds, average='weighted', multi_class='ovr')

    # Confusion matrix and sensitivity/specificity
    cm = confusion_matrix(test_targets, preds_class)
    tn, fp, fn, tp = cm.ravel() if len(cm.ravel()) == 4 else [0, 0, 0, 0]  # Handle cases with binary classification only
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0

    # Append metrics to the report
    report['auc'] = auc
    report['specificity'] = specificity
    report['sensitivity'] = sensitivity

    return report

# Evaluate all models
models = [densenet_focal, densenet_apl, densenet_bce, cnn_focal, cnn_apl, cnn_bce]
model_names = ['DenseNet FocalLoss', 'DenseNet Categorical cross-entropy', 'DenseNet Binary Cross-Entropy',
               'CNN FocalLoss', 'CNN Categorical cross-entropy', 'CNN Binary Cross-Entropy']
metrics_list = []

for model, name in zip(models, model_names):
    report = evaluate_model(model, test_data, val_targets_categorical, name)
    metrics_list.append({
        'Model': name,
        'accuracy': report['accuracy'],
        'auc': report['auc'],
        'specificity': report['specificity'],
        'sensitivity': report['sensitivity']
    })

# Create a DataFrame for the metrics
metrics_df = pd.DataFrame(metrics_list)

# Save to CSV
metrics_df.to_csv('drive/MyDrive/Confusion_matrix/model_metrics.csv', index=False)

# Print summary
print(metrics_df)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                            Model  accuracy       auc  specificity  sensitivity
# 0             DenseNet FocalLoss     0.775  0.825216     0.801370     0.703704
# 1               DenseNet APLLoss     0.730  0.518904     1.000000     0.000000
# 2  DenseNet Binary Cross-Entropy     0.780  0.872638     0.780822     0.777778
# 3                  CNN FocalLoss     0.730  0.410913     1.000000     0.000000
# 4                    CNN APLLoss     0.730  0.618848     1.000000     0.000000
# 5       CNN Binary Cross-Entropy     0.270  0.592483     0.000000     1.000000

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

# Function to evaluate the model
def evaluate_model(model, test_data, test_targets_onehot, model_name):
    # Predict the probabilities for the test data
    preds = model.predict(test_data)
    # Convert predicted probabilities to class labels
    preds_class = np.argmax(preds, axis=1)
    # Convert one-hot encoded test targets back to 1D labels
    test_targets = np.argmax(test_targets_onehot, axis=1)

    # Compute classification report metrics
    report = classification_report(test_targets, preds_class, output_dict=True)

    # Compute AUC (weighted for multiclass)
    auc = roc_auc_score(test_targets_onehot, preds, average='weighted', multi_class='ovr')

    # Compute confusion matrix
    cm = confusion_matrix(test_targets, preds_class)

    # Handle binary or multiclass confusion matrix accordingly
    if len(cm.ravel()) == 4:  # Binary classification
        tn, fp, fn, tp = cm.ravel()
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    else:  # Multiclass
        specificity = None  # Specificity and sensitivity are for binary classification only
        sensitivity = None

    # Append AUC, specificity, and sensitivity to the report
    report['overall'] = {
        'accuracy': report['accuracy'],
        'auc': auc,
        'specificity': specificity,
        'sensitivity': sensitivity
    }

    return report

# Evaluate all models
models = [densenet_focal, densenet_apl, densenet_bce, cnn_focal, cnn_apl, cnn_bce]
model_names = ['DenseNet FocalLoss', 'DenseNet Categorical cross-entropy', 'DenseNet Binary Cross-Entropy',
               'CNN FocalLoss', 'CNN Categorical cross-entropy', 'CNN Binary Cross-Entropy']

# List to store the metrics for each model
metrics_list = []

# Evaluate each model and gather the metrics
for model, name in zip(models, model_names):
    report = evaluate_model(model, test_data, val_targets_categorical, name)

    # Flatten the dictionary to store all metrics
    flattened_report = {}
    for key, value in report.items():
        if isinstance(value, dict):
            for metric, metric_value in value.items():
                flattened_report[f'{key}_{metric}'] = metric_value
        else:
            flattened_report[key] = value

    # Add model name
    flattened_report['Model'] = name
    metrics_list.append(flattened_report)

# Create a DataFrame with all the metrics
metrics_df = pd.DataFrame(metrics_list)

# Save the metrics to CSV
metrics_df.to_csv('drive/MyDrive/Confusion_matrix/full_model_metrics.csv', index=False)

# Print the DataFrame for a quick overview
print(metrics_df)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#    0_precision  0_recall  0_f1-score  0_support  1_precision  1_recall  \
# 0     0.879699  0.801370    0.838710      146.0     0.567164  0.703704
# 1     0.730000  1.000000    0.843931      146.0     0.000000  0.000000
# 2     0.904762  0.780822    0.838235      146.0     0.567568  0.777778
# 3     0.730000  1.000000    0.843931      146.0     0.000000  0.000000
# 4     0.730000  1.000000    0.843931      146.0     0.000000  0.000000
# 5     0.000000  0.000000    0.000000      146.0     0.270000  1.000000
#
#    1_f1-score  1_support  accuracy  macro avg_precision  ...  \
# 0    0.628099       54.0     0.775             0.723432  ...
# 1    0.000000       54.0     0.730             0.365000  ...
# 2    0.656250       54.0     0.780             0.736165  ...
# 3    0.000000       54.0     0.730             0.365000  ...
# 4    0.000000       54.0     0.730             0.365000  ...
# 5    0.425197       54.0     0.270             0.135000  ...
#
#    macro avg_support  weighted avg_precision  weighted avg_recall  \
# 0              200.0                0.795315                0.775
# 1              200.0                0.532900                0.730
# 2              200.0                0.813719                0.780
# 3              200.0                0.532900                0.730
# 4              200.0                0.532900                0.730
# 5              200.0                0.072900                0.270
#
#    weighted avg_f1-score  weighted avg_support  overall_accuracy  overall_auc  \
# 0               0.781845                 200.0             0.775     0.825216
# 1               0.616069                 200.0             0.730     0.518904
# 2               0.789099                 200.0             0.780     0.872638
# 3               0.616069                 200.0             0.730     0.410913
# 4               0.616069                 200.0             0.730     0.618848
# 5               0.114803                 200.0             0.270     0.592483
#
#    overall_specificity  overall_sensitivity                          Model
# 0             0.801370             0.703704             DenseNet FocalLoss
# 1             1.000000             0.000000               DenseNet APLLoss
# 2             0.780822             0.777778  DenseNet Binary Cross-Entropy
# 3             1.000000             0.000000                  CNN FocalLoss
# 4             1.000000             0.000000                    CNN APLLoss
# 5             0.000000             1.000000       CNN Binary Cross-Entropy
#
# [6 rows x 22 columns]

# %% [markdown]
# ## Confusion Matrix

# %%
# List of model configurations and their corresponding names
model_names = ['DenseNet_Focal', 'DenseNet_Categorical cross-entropy', 'DenseNet_BCE',
               'CNN_Focal', 'CNN_Categorical cross-entropy', 'CNN_BCE']

# Store predictions for each model (replace these variables with actual predictions)
model_predictions = [densenet_focal_preds, densenet_apl_preds, densenet_bce_preds,
                     cnn_focal_preds, cnn_apl_preds, cnn_bce_preds]

# Convert the categorical test targets back to integer labels if necessary
true_labels = test_targets  # Assuming this is already in integer format

# Create subplots for confusion matrices
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.ravel()  # Flatten the axes for easy iteration

# Create 'Confusion_matrix' directory if it doesn't exist
os.makedirs('Confusion_matrix', exist_ok=True)

# Loop through the models and generate confusion matrices
for i, model_name in enumerate(model_names):
    # Compute confusion matrix
    cm = confusion_matrix(true_labels, model_predictions[i])

    # Plot confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', ax=axes[i],
                xticklabels=classes, yticklabels=classes)
    axes[i].set_title(f'Confusion Matrix: {model_name}')
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('True')

    # Save each confusion matrix separately
    plt.savefig(f'drive/MyDrive/Confusion_matrix/{model_name}_confusion_matrix.png')

# Adjust the layout for clarity
plt.tight_layout()

# Show the plot
plt.show()
